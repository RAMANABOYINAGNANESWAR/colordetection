# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/PNG.jpg')


hsv_img=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
lower_color=np.array([90,50,50])
upper_color=np.array([130,255,255])



color_mask=cv2.inRange(hsv_img,lower_color,upper_color)
result=cv2.bitwise_and(img,img,mask=color_mask)
cv2_imshow(img)
print('')
cv2_imshow(result)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=256x252>
# <PIL.Image.Image image mode=RGB size=256x252>

# %%
lower_color=np.array([0,50,50])
upper_color=np.array([10,255,255])
color_mask=cv2.inRange(hsv_img,lower_color,upper_color)
result=cv2.bitwise_and(img,img,mask=color_mask)
cv2_imshow(img)
print('')
cv2_imshow(result)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=256x252>
# <PIL.Image.Image image mode=RGB size=256x252>

# %%
lower_color=np.array([35,50,50])
upper_color=np.array([85,255,255])


color_mask=cv2.inRange(hsv_img,lower_color,upper_color)
result=cv2.bitwise_and(img,img,mask=color_mask)
cv2_imshow(img)
print('')
cv2_imshow(result)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=256x252>
# <PIL.Image.Image image mode=RGB size=256x252>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/color.jpg')


hsv_img=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
lower_color=np.array([80,50,50])
upper_color=np.array([110,255,255])



color_mask=cv2.inRange(hsv_img,lower_color,upper_color)
result=cv2.bitwise_and(img,img,mask=color_mask)
cv2_imshow(img)
print('')
cv2_imshow(result)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x662>
# <PIL.Image.Image image mode=RGB size=1000x662>
